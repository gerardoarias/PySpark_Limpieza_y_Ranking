# %% [markdown]
# # PySpark: Reto Restaurantes Tacos&Burritos
#
# Autor: Gerardo Andrés Arias Remolina
#
# github: gerardoarias

# %% [markdown]
# A continuación disponemos de una base de datos proveniente de [Kaggle](https://www.kaggle.com/datafiniti/restaurants-burritos-and-tacos). En ella se encuentran cerca de 20000 observaciones relacionadas con restaurantes o pequeños negocios que ofrecen dentro de sus menus tacos o burritos (aunque no es lo que exclusivamente ofrecen). El objetivo de este reto será usar PySpark para limpiar la base de datos y con las herramientas con las que dispone Spark poder generar un ranking de los tipos de cocina más populares dentro de esta muestra.

# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.2.0.tar.gz (281.3 MB)
#      |████████████████████████████████| 281.3 MB 42 kB/s
# Collecting py4j==0.10.9.2
#   Downloading py4j-0.10.9.2-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 51.6 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.2.0-py2.py3-none-any.whl size=281805912 sha256=5c2345772069e754ecbebc44cff77a388d5413ff45de04ef4800dd524140db17
#   Stored in directory: /root/.cache/pip/wheels/0b/de/d2/9be5d59d7331c6c2a7c1b6d1a4f463ce107332b1ecd4e80718
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.2 pyspark-3.2.0

# %%
# Con esta función descomprimimos un archivo .zip donde se encuentra el dataset en el entorno de Google Colab
import zipfile

ruta_zip = "/content/drive/MyDrive/BD_GoogleColab/BD_Restaurantes_TacosBurritos.zip"
ruta_extraccion = "/content"
password = None
archivo_zip = zipfile.ZipFile(ruta_zip, "r")
try:
    print(archivo_zip.namelist())
    archivo_zip.extractall(pwd=password, path=ruta_extraccion)
except:
    pass
archivo_zip.close()
# Out:
# ['just tacos and burritos.csv']

# %% [markdown]
# Primero configuramos el contexto de  Spark (SparkContext). Ello es clave porque este contexto es el motor interno que nos permite conectarnos con los clusters. Además, resulta clave configurar el motor con diferentes fuentes de datos. Por eso cargamos SQLContext, facilitando así las funcionalidades de SQL.
#
# Igualmente cargamos el dataset de interés indicándole que está en formato de texto plano csv, que tiene encabezado, y le indicamos la ubicación. Además con inferSchema = true, le indicamos a Spark que infiera el tipo de datos para cada una de las variables.

# %%
from pyspark import SparkConf, SparkContext
from pyspark.sql.types import StringType
from pyspark import SQLContext

conf = SparkConf().setMaster('local').setAppName('Mi programa')
sc = SparkContext(conf = conf) 
sqlContext = SQLContext(sc)

dfspark = sqlContext.read.format('csv').option('header','true').option('inferSchema','true').load('/content/just tacos and burritos.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/pyspark/sql/context.py:79: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   FutureWarning

# %%
dfspark.show(5)
# Out:
# +--------------------+--------------------+--------------------+-----------+-------+--------------------+-------------------+-------------------+--------------------+----------+------------+--------------------+---------------+---------------+--------------+--------------+--------------------+--------------------+-----------------+--------------------+----------+------------------+-------------+-------------+------------+--------------------+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |                  id|             address|          categories|       city|country|            cuisines|          dateAdded|        dateUpdated|                keys|  latitude|   longitude|         menuPageURL|menus.amountMax|menus.amountMin|menus.category|menus.currency|      menus.dateSeen|   menus.description|       menus.name|                name|postalCode|priceRangeCurrency|priceRangeMin|priceRangeMax|    province|            websites|_c26|_c27|_c28|_c29|_c30|_c31|_c32|_c33|_c34|_c35|_c36|_c37|_c38|_c39|_c40|_c41|_c42|_c43|_c44|_c45|_c46|_c47|_c48|_c49|_c50|_c51|_c52|_c53|_c54|_c55|_c56|_c57|_c58|_c59|_c60|_c61|_c62|_c63|_c64|_c65|_c66|_c67|_c68|_c69|_c70|_c71|_c72|_c73|_c74|_c75|_c76|_c77|_c78|_c79|_c80|_c81|_c82|_c83|_c84|_c85|_c86|_c87|_c88|_c89|_c90|_c91|_c92|_c93|_c94|_c95|_c96|_c97|_c98|_c99|_c100|_c101|_c102|_c103|_c104|_c105|_c106|_c107|_c108|_c109|_c110|_c111|_c112|_c113|_c114|_c115|_c116|_c117|_c118|_c119|_c120|_c121|_c122|_c123|_c124|_c125|_c126|_c127|_c128|_c129|_c130|_c131|_c132|_c133|_c134|_c135|_c136|_c137|_c138|_c139|_c140|_c141|_c142|_c143|_c144|_c145|_c146|_c147|_c148|_c149|_c150|_c151|_c152|_c153|_c154|_c155|_c156|_c157|_c158|_c159|_c160|_c161|_c162|_c163|_c164|_c165|_c166|_c167|_c168|_c169|_c170|_c171|_c172|_c173|_c174|_c175|_c176|_c177|_c178|_c179|_c180|_c181|_c182|_c183|_c184|_c185|_c186|_c187|_c188|_c189|_c190|_c191|_c192|_c193|_c194|_c195|_c196|_c197|_c198|_c199|_c200|_c201|_c202|_c203|_c204|_c205|_c206|_c207|_c208|_c209|_c210|_c211|_c212|_c213|_c214|_c215|_c216|_c217|_c218|_c219|_c220|_c221|_c222|_c223|_c224|_c225|_c226|_c227|_c228|_c229|_c230|_c231|_c232|_c233|_c234|_c235|
# +--------------------+--------------------+--------------------+-----------+-------+--------------------+-------------------+-------------------+--------------------+----------+------------+--------------------+---------------+---------------+--------------+--------------+--------------------+--------------------+-----------------+--------------------+----------+------------------+-------------+-------------+------------+--------------------+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |AVwc__cikufWRAb51QjV|   610 Commercial St|Restaurant Delive...|   Atchison|     US|Restaurant Delive...|2016-03-02 11:49:34|2017-02-01 18:04:44|us/ks/atchison/61...|  39.56157|   -95.12102|http://www.yellow...|           null|           null|          null|          null|2017-02-01T18:04:44Z|                null|             Taco|     Gambino's Pizza|     66002|              null|         null|         null|          KS|http://www.gambin...|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null|
# |AVwc__cikufWRAb51QjV|   610 Commercial St|Restaurant Delive...|   Atchison|     US|Restaurant Delive...|2016-03-02 11:49:34|2017-02-01 18:04:44|us/ks/atchison/61...|  39.56157|   -95.12102|http://www.yellow...|           null|           null|          null|          null|2016-03-02T11:49:34Z|Beef, onion, ched...|             Taco|     Gambino's Pizza|     66002|              null|         null|         null|          KS|http://www.gambin...|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null|
# |AVwc__dF_7pvs4fz1Ncy|9521 Morton Davis Dr|Golf Course, Amer...|  Patterson|     US|                null|2016-10-14 01:58:25|2016-10-14 01:58:25|us/grayson/patter...| 37.401855| -121.266703|                null|           null|           null|          null|          null|2016-10-14T01:58:25Z|Beef barbacoa or ...| Smotherd Burrito|Diablo Grande Gol...|     95363|              null|         null|         null|     Grayson|http://www.diablo...|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null|
# |AVwc__kCByjofQCxkdm-|10550 W I 25 Fron...|Fast Food Restaurant|   Longmont|     US|                null|2016-09-09 17:30:34|2016-10-04 05:15:17|us/niwot/longmont...|      null|        null|                null|           null|           null|          null|          null|2016-09-09T17:30:34Z|                null|  Sausage Burrito|          Mcdonald's|     80504|              null|         null|         null|       Niwot|http://mcdonalds.com|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null|
# |AVwc__WtByjofQCxkdkR|       8495 W 3rd St|Mexican Restauran...|Los Angeles|     US|             Mexican|2016-05-19 11:50:25|2016-09-11 00:06:37|us/bicentennial/l...|34.0807243|-118.3895776|                null|           null|           null|          null|          null|2016-05-19T11:50:25Z|Wahoo, avocado, c...|Wahoo Tacogrilled|Baja Fresh Mexica...|     90048|               USD|            0|           25|Bicentennial|http://bajafresh.com|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null|null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null| null|
# +--------------------+--------------------+--------------------+-----------+-------+--------------------+-------------------+-------------------+--------------------+----------+------------+--------------------+---------------+---------------+--------------+--------------+--------------------+--------------------+-----------------+--------------------+----------+------------------+-------------+-------------+------------+--------------------+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# only showing top 5 rows

# %% [markdown]
# Ahora filtramos el dataset para que no hallan observaciones de nuestra variable de interés (cuisines) nulas.

# %%
dfspark = dfspark.filter('cuisines is not NULL')

# %% [markdown]
# Revisamos el tipo de variables que Spark ha inferido. A pesar de que Spark se aproxima muy bien al tipo de variables, es importante revisarlas porque pudo haber catalogado algunas de ellas como objetos e impedir con ello la ejecución correcto de nuestro modelo.
#
# Adicionalmente, podemos identificar columnas adicionales que por error se hayan considerado como variables y que no lo sean.

# %%
dfspark.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- categories: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- cuisines: string (nullable = true)
#  |-- dateAdded: timestamp (nullable = true)
#  |-- dateUpdated: timestamp (nullable = true)
#  |-- keys: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- menuPageURL: string (nullable = true)
#  |-- menus.amountMax: double (nullable = true)
#  |-- menus.amountMin: double (nullable = true)
#  |-- menus.category: string (nullable = true)
#  |-- menus.currency: string (nullable = true)
#  |-- menus.dateSeen: string (nullable = true)
#  |-- menus.description: string (nullable = true)
#  |-- menus.name: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- postalCode: string (nullable = true)
#  |-- priceRangeCurrency: string (nullable = true)
#  |-- priceRangeMin: integer (nullable = true)
#  |-- priceRangeMax: integer (nullable = true)
#  |-- province: string (nullable = true)
#  |-- websites: string (nullable = true)
#  |-- _c26: string (nullable = true)
#  |-- _c27: string (nullable = true)
#  |-- _c28: string (nullable = true)
#  |-- _c29: string (nullable = true)
#  |-- _c30: string (nullable = true)
#  |-- _c31: string (nullable = true)
#  |-- _c32: string (nullable = true)
#  |-- _c33: string (nullable = true)
#  |-- _c34: string (nullable = true)
#  |-- _c35: string (nullable = true)
#  |-- _c36: string (nullable = true)
#  |-- _c37: string (nullable = true)
#  |-- _c38: string (nullable = true)
#  |-- _c39: string (nullable = true)
#  |-- _c40: string (nullable = true)
#  |-- _c41: string (nullable = true)
#  |-- _c42: string (nullable = true)
#  |-- _c43: string (nullable = true)
#  |-- _c44: string (nullable = true)
#  |-- _c45: string (nullable = true)
#  |-- _c46: string (nullable = true)
#  |-- _c47: string (nullable = true)
#  |-- _c48: string (nullable = true)
#  |-- _c49: string (nullable = true)
#  |-- _c50: string (nullable = true)
#  |-- _c51: string (nullable = true)
#  |-- _c52: string (nullable = true)
#  |-- _c53: string (nullable = true)
#  |-- _c54: string (nullable = true)
#  |-- _c55: string (nullable = true)
#  |-- _c56: string (nullable = true)
#  |-- _c57: string (nullable = true)
#  |-- _c58: string (nullable = true)
#  |-- _c59: string (nullable = true)
#  |-- _c60: string (nullable = true)
#  |-- _c61: string (nullable = true)
#  |-- _c62: string (nullable = true)
#  |-- _c63: string (nullable = true)
#  |-- _c64: string (nullable = true)
#  |-- _c65: string (nullable = true)
#  |-- _c66: string (nullable = true)
#  |-- _c67: string (nullable = true)
#  |-- _c68: string (nullable = true)
#  |-- _c69: string (nullable = true)
#  |-- _c70: string (nullable = true)
#  |-- _c71: string (nullable = true)
#  |-- _c72: string (nullable = true)
#  |-- _c73: string (nullable = true)
#  |-- _c74: string (nullable = true)
#  |-- _c75: string (nullable = true)
#  |-- _c76: string (nullable = true)
#  |-- _c77: string (nullable = true)
#  |-- _c78: string (nullable = true)
#  |-- _c79: string (nullable = true)
#  |-- _c80: string (nullable = true)
#  |-- _c81: string (nullable = true)
#  |-- _c82: string (nullable = true)
#  |-- _c83: string (nullable = true)
#  |-- _c84: string (nullable = true)
#  |-- _c85: string (nullable = true)
#  |-- _c86: string (nullable = true)
#  |-- _c87: string (nullable = true)
#  |-- _c88: string (nullable = true)
#  |-- _c89: string (nullable = true)
#  |-- _c90: string (nullable = true)
#  |-- _c91: string (nullable = true)
#  |-- _c92: string (nullable = true)
#  |-- _c93: string (nullable = true)
#  |-- _c94: string (nullable = true)
#  |-- _c95: string (nullable = true)
#  |-- _c96: string (nullable = true)
#  |-- _c97: string (nullable = true)
#  |-- _c98: string (nullable = true)
#  |-- _c99: string (nullable = true)
#  |-- _c100: string (nullable = true)
#  |-- _c101: string (nullable = true)
#  |-- _c102: string (nullable = true)
#  |-- _c103: string (nullable = true)
#  |-- _c104: string (nullable = true)
#  |-- _c105: string (nullable = true)
#  |-- _c106: string (nullable = true)
#  |-- _c107: string (nullable = true)
#  |-- _c108: string (nullable = true)
#  |-- _c109: string (nullable = true)
#  |-- _c110: string (nullable = true)
#  |-- _c111: string (nullable = true)
#  |-- _c112: string (nullable = true)
#  |-- _c113: string (nullable = true)
#  |-- _c114: string (nullable = true)
#  |-- _c115: string (nullable = true)
#  |-- _c116: string (nullable = true)
#  |-- _c117: string (nullable = true)
#  |-- _c118: string (nullable = true)
#  |-- _c119: string (nullable = true)
#  |-- _c120: string (nullable = true)
#  |-- _c121: string (nullable = true)
#  |-- _c122: string (nullable = true)
#  |-- _c123: string (nullable = true)
#  |-- _c124: string (nullable = true)
#  |-- _c125: string (nullable = true)
#  |-- _c126: string (nullable = true)
#  |-- _c127: string (nullable = true)
#  |-- _c128: string (nullable = true)
#  |-- _c129: string (nullable = true)
#  |-- _c130: string (nullable = true)
#  |-- _c131: string (nullable = true)
#  |-- _c132: string (nullable = true)
#  |-- _c133: string (nullable = true)
#  |-- _c134: string (nullable = true)
#  |-- _c135: string (nullable = true)
#  |-- _c136: string (nullable = true)
#  |-- _c137: string (nullable = true)
#  |-- _c138: string (nullable = true)
#  |-- _c139: string (nullable = true)
#  |-- _c140: string (nullable = true)
#  |-- _c141: string (nullable = true)
#  |-- _c142: string (nullable = true)
#  |-- _c143: string (nullable = true)
#  |-- _c144: string (nullable = true)
#  |-- _c145: string (nullable = true)
#  |-- _c146: string (nullable = true)
#  |-- _c147: string (nullable = true)
#  |-- _c148: string (nullable = true)
#  |-- _c149: string (nullable = true)
#  |-- _c150: string (nullable = true)
#  |-- _c151: string (nullable = true)
#  |-- _c152: string (nullable = true)
#  |-- _c153: string (nullable = true)
#  |-- _c154: string (nullable = true)
#  |-- _c155: string (nullable = true)
#  |-- _c156: string (nullable = true)
#  |-- _c157: string (nullable = true)
#  |-- _c158: string (nullable = true)
#  |-- _c159: string (nullable = true)
#  |-- _c160: string (nullable = true)
#  |-- _c161: string (nullable = true)
#  |-- _c162: string (nullable = true)
#  |-- _c163: string (nullable = true)
#  |-- _c164: string (nullable = true)
#  |-- _c165: string (nullable = true)
#  |-- _c166: string (nullable = true)
#  |-- _c167: string (nullable = true)
#  |-- _c168: string (nullable = true)
#  |-- _c169: string (nullable = true)
#  |-- _c170: string (nullable = true)
#  |-- _c171: string (nullable = true)
#  |-- _c172: string (nullable = true)
#  |-- _c173: string (nullable = true)
#  |-- _c174: string (nullable = true)
#  |-- _c175: string (nullable = true)
#  |-- _c176: string (nullable = true)
#  |-- _c177: string (nullable = true)
#  |-- _c178: string (nullable = true)
#  |-- _c179: string (nullable = true)
#  |-- _c180: string (nullable = true)
#  |-- _c181: string (nullable = true)
#  |-- _c182: string (nullable = true)
#  |-- _c183: string (nullable = true)
#  |-- _c184: string (nullable = true)
#  |-- _c185: string (nullable = true)
#  |-- _c186: string (nullable = true)
#  |-- _c187: string (nullable = true)
#  |-- _c188: string (nullable = true)
#  |-- _c189: string (nullable = true)
#  |-- _c190: string (nullable = true)
#  |-- _c191: string (nullable = true)
#  |-- _c192: string (nullable = true)
#  |-- _c193: string (nullable = true)
#  |-- _c194: string (nullable = true)
#  |-- _c195: string (nullable = true)
#  |-- _c196: string (nullable = true)
#  |-- _c197: string (nullable = true)
#  |-- _c198: string (nullable = true)
#  |-- _c199: string (nullable = true)
#  |-- _c200: string (nullable = true)
#  |-- _c201: string (nullable = true)
#  |-- _c202: string (nullable = true)
#  |-- _c203: string (nullable = true)
#  |-- _c204: string (nullable = true)
#  |-- _c205: string (nullable = true)
#  |-- _c206: string (nullable = true)
#  |-- _c207: string (nullable = true)
#  |-- _c208: string (nullable = true)
#  |-- _c209: string (nullable = true)
#  |-- _c210: string (nullable = true)
#  |-- _c211: string (nullable = true)
#  |-- _c212: string (nullable = true)
#  |-- _c213: string (nullable = true)
#  |-- _c214: string (nullable = true)
#  |-- _c215: string (nullable = true)
#  |-- _c216: string (nullable = true)
#  |-- _c217: string (nullable = true)
#  |-- _c218: string (nullable = true)
#  |-- _c219: string (nullable = true)
#  |-- _c220: string (nullable = true)
#  |-- _c221: string (nullable = true)
#  |-- _c222: string (nullable = true)
#  |-- _c223: string (nullable = true)
#  |-- _c224: string (nullable = true)
#  |-- _c225: string (nullable = true)
#  |-- _c226: string (nullable = true)
#  |-- _c227: string (nullable = true)
#  |-- _c228: string (nullable = true)
#  |-- _c229: string (nullable = true)
#  |-- _c230: string (nullable = true)
#  |-- _c231: string (nullable = true)
#  |-- _c232: string (nullable = true)
#  |-- _c233: string (nullable = true)
#  |-- _c234: string (nullable = true)
#  |-- _c235: string (nullable = true)

# %% [markdown]
# Aislamos la columna de interés en donde se encuentran los tipos de cocina.

# %%
A = sc.parallelize(dfspark.select('cuisines').rdd.collect())

# %% [markdown]
# Hacemos este objeto persistente en memoria

# %%
A.persist()
# Out:
# ParallelCollectionRDD[20] at readRDDFromFile at PythonRDD.scala:274

# %% [markdown]
# Revisamos el detalle del contenido del objeto. Encontramos que los string de tipo de cocina incluyen espacios y que cada tipo de cocina se encuentra separado por comas. Por lo que posteriormente limpiaremos esto y separaremos por comas con ayuda de una función.

# %%
A.collect()
# Out:
# [Row(cuisines='Restaurant Delivery Service'),
#  Row(cuisines='Restaurant Delivery Service'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Coffee Shops'),
#  Row(cuisines='Coffee Shops'),
#  Row(cuisines='Coffee Shops'),
#  Row(cuisines='Mexican, Latin American'),
#  Row(cuisines='Mexican, Latin American'),
#  Row(cuisines='American,Seafood Restaurants'),
#  Row(cuisines='American,Seafood Restaurants'),
#  Row(cuisines='American,Seafood Restaurants'),
#  Row(cuisines='American,Seafood Restaurants'),
#  Row(cuisines='American,Seafood Restaurants'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Pizza'),
#  Row(cuisines='Pizza'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Seafood,Seafood Restaurants'),
#  Row(cuisines='Japanese, Thai, Hibachi'),
#  Row(cuisines='Contemporary American, Wine Bar, Afternoon Tea'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Pizza'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='American (New)'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Contemporary American, Comfort Food, Seafood'),
#  Row(cuisines='Contemporary American, Comfort Food, Seafood'),
#  Row(cuisines='Hamburgers, Fries, Shakes, Salads,Take Out Restaurants'),
#  Row(cuisines='Pizza'),
#  Row(cuisines='Fast Food'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Contemporary American, Bar / Lounge / Bottle Service'),
#  Row(cuisines='Contemporary American, Bar / Lounge / Bottle Service'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Contemporary American'),
#  Row(cuisines='Contemporary American'),
#  Row(cuisines='Contemporary American'),
#  Row(cuisines='Contemporary American'),
#  Row(cuisines='Contemporary American'),
#  Row(cuisines='Contemporary American'),
#  Row(cuisines='Contemporary American'),
#  Row(cuisines='Yogurt'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Bars'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Traditional American,Health Food,Pizza,Asian Fusion'),
#  Row(cuisines='Traditional American,Health Food,Pizza,Asian Fusion'),
#  Row(cuisines='Traditional American,Health Food,Pizza,Asian Fusion'),
#  Row(cuisines='Traditional American,Health Food,Pizza,Asian Fusion'),
#  Row(cuisines='Traditional American,Health Food,Pizza,Asian Fusion'),
#  Row(cuisines='American, Bar / Lounge / Bottle Service'),
#  Row(cuisines='American, Bar / Lounge / Bottle Service'),
#  Row(cuisines='American, Bar / Lounge / Bottle Service'),
#  Row(cuisines='Night Clubs'),
#  Row(cuisines='Night Clubs'),
#  Row(cuisines='American Restaurants,American, Contemporary American, Southern'),
#  Row(cuisines='American Restaurants,American, Contemporary American, Southern'),
#  Row(cuisines='American Restaurants,American, Contemporary American, Southern'),
#  Row(cuisines='Taverns'),
#  Row(cuisines='Taverns'),
#  Row(cuisines='New American,Traditional American,Fast Food,Hamburgers'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Coffee Shops'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='American'),
#  Row(cuisines='American'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Fast Food,Hamburgers'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Pizza'),
#  Row(cuisines='Contemporary American, Global, International'),
#  Row(cuisines='Contemporary American, Global, International'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Pizzeria, Barbecue'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Fast Food'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Italian'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Caterers'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='Traditional American,Sandwich Shops'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Sandwich Shops,Restaurants'),
#  Row(cuisines='Coffee Shops'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='New American'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='American, Contemporary American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Bars'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Japanese Restaurants'),
#  Row(cuisines='American'),
#  Row(cuisines='American'),
#  Row(cuisines='American'),
#  Row(cuisines='Pizza,Take Out Restaurants'),
#  Row(cuisines='Hamburgers'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Coffee Shops'),
#  Row(cuisines='Coffee Shops'),
#  Row(cuisines='Coffee Shops'),
#  Row(cuisines='American'),
#  Row(cuisines='American'),
#  Row(cuisines='American'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Pizza'),
#  Row(cuisines='Fast Food'),
#  Row(cuisines='American'),
#  Row(cuisines='Contemporary American, American'),
#  Row(cuisines='Japanese Restaurants'),
#  Row(cuisines='American,Vegetarian Friendly,Vegan Options,Gluten Free Options'),
#  Row(cuisines='American,Vegetarian Friendly,Vegan Options,Gluten Free Options'),
#  Row(cuisines='American,Vegetarian Friendly,Vegan Options,Gluten Free Options'),
#  Row(cuisines='American,Vegetarian Friendly,Vegan Options,Gluten Free Options'),
#  Row(cuisines='American Restaurants,American'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='American'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Coffee Shops'),
#  Row(cuisines='Coffee Shops'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Pub'),
#  Row(cuisines='Burgers'),
#  Row(cuisines='Burgers'),
#  Row(cuisines='Burgers'),
#  Row(cuisines='Burgers'),
#  Row(cuisines='Italian'),
#  Row(cuisines='American'),
#  Row(cuisines='American'),
#  Row(cuisines='American, Comfort Food, Gastro Pub'),
#  Row(cuisines='American, Comfort Food, Gastro Pub'),
#  Row(cuisines='Coffee Shops'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican, Latin / Spanish, Contemporary Mexican'),
#  Row(cuisines='Mexican, Latin / Spanish, Contemporary Mexican'),
#  Row(cuisines='Seafood, Fusion / Eclectic, Lounge'),
#  Row(cuisines='Seafood, Fusion / Eclectic, Lounge'),
#  Row(cuisines='Seafood'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Take Out Restaurants,Latin American Restaurants'),
#  Row(cuisines='American, Contemporary American'),
#  Row(cuisines='Tex-Mex, Mexican'),
#  Row(cuisines='Tex-Mex, Mexican'),
#  Row(cuisines='Tex-Mex, Mexican'),
#  Row(cuisines='Fast Food,Hamburgers,Fast Food Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Burgers'),
#  Row(cuisines='Burgers'),
#  Row(cuisines='Contemporary American, American'),
#  Row(cuisines='American, Contemporary French / American, Creole / Cajun / Southern'),
#  Row(cuisines='Chicken Restaurants'),
#  Row(cuisines='Chicken Restaurants'),
#  Row(cuisines='Chicken Restaurants'),
#  Row(cuisines='American'),
#  Row(cuisines='American'),
#  Row(cuisines='American'),
#  Row(cuisines='American'),
#  Row(cuisines='American'),
#  Row(cuisines='American'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='American, Diner, Delicatessen'),
#  Row(cuisines='American, Diner, Delicatessen'),
#  Row(cuisines='Tex-Mex'),
#  Row(cuisines='American'),
#  Row(cuisines='Pizza,Taverns'),
#  Row(cuisines='Pizza,Taverns'),
#  Row(cuisines='Pizza,Taverns'),
#  Row(cuisines='Pizza,Taverns'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Bars,American Restaurants'),
#  Row(cuisines='Pizza'),
#  Row(cuisines='Cafeterias'),
#  Row(cuisines='Cafeterias'),
#  Row(cuisines='Cafeterias'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='Tapas / Small Plates, Bar / Lounge / Bottle Service'),
#  Row(cuisines='Tapas / Small Plates, Bar / Lounge / Bottle Service'),
#  Row(cuisines='Tapas / Small Plates, Bar / Lounge / Bottle Service'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Pizza'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Restaurants,American'),
#  Row(cuisines='Italian, Mediterranean, Wine Bar'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Pizza'),
#  Row(cuisines='Vegetarian'),
#  Row(cuisines='Pizza,Italian'),
#  Row(cuisines='Greek'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='American, Comfort Food'),
#  Row(cuisines='American'),
#  Row(cuisines='American'),
#  Row(cuisines='Yogurt'),
#  Row(cuisines='Pizza,Take Out Restaurants'),
#  Row(cuisines='Pizza,Take Out Restaurants'),
#  Row(cuisines='Bagels'),
#  Row(cuisines='Comfort Food, Californian, Contemporary American'),
#  Row(cuisines='Comfort Food, Californian, Contemporary American'),
#  Row(cuisines='Hamburgers'),
#  Row(cuisines='Hamburgers'),
#  Row(cuisines='Hamburgers'),
#  Row(cuisines='Hamburgers'),
#  Row(cuisines='Italian,American Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='American'),
#  Row(cuisines='Hamburgers'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Bars,American'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Fast Food'),
#  Row(cuisines='Vegetarian / Vegan, Global, International, Organic'),
#  Row(cuisines='Vegetarian / Vegan, Global, International, Organic'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Fast Food'),
#  Row(cuisines='Coffee Shops'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Italian,Pizza,Take Out Restaurants'),
#  Row(cuisines='Italian,Pizza,Take Out Restaurants'),
#  Row(cuisines='Italian,Pizza,Take Out Restaurants'),
#  Row(cuisines='Italian,Pizza,Take Out Restaurants'),
#  Row(cuisines='Italian,Pizza,Take Out Restaurants'),
#  Row(cuisines='Italian,Pizza,Take Out Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='Caterers'),
#  Row(cuisines='Caterers'),
#  Row(cuisines='Caterers'),
#  Row(cuisines='Caterers'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='American, Steak, Seafood'),
#  Row(cuisines='American, Steak, Seafood'),
#  Row(cuisines='American, Steak, Seafood'),
#  Row(cuisines='American, Steak, Seafood'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Bars'),
#  Row(cuisines='Bars'),
#  Row(cuisines='Pizza,Mediterranean'),
#  Row(cuisines='Vegan'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Latin American, Steak, Seafood'),
#  Row(cuisines='Latin American, Steak, Seafood'),
#  Row(cuisines='Latin American, Steak, Seafood'),
#  Row(cuisines='Latin American, Steak, Seafood'),
#  Row(cuisines='Latin American, Steak, Seafood'),
#  Row(cuisines='Latin American, Steak, Seafood'),
#  Row(cuisines='Latin American, Steak, Seafood'),
#  Row(cuisines='Family Style Restaurants'),
#  Row(cuisines='Family Style Restaurants'),
#  Row(cuisines='Family Style Restaurants'),
#  Row(cuisines='Family Style Restaurants'),
#  Row(cuisines='Family Style Restaurants'),
#  Row(cuisines='Family Style Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican,Traditional American'),
#  Row(cuisines='Mexican,Traditional American'),
#  Row(cuisines='Mexican,Traditional American'),
#  Row(cuisines='Mexican,Traditional American'),
#  Row(cuisines='Mexican,Traditional American'),
#  Row(cuisines='Mexican,Traditional American'),
#  Row(cuisines='Mexican,Traditional American'),
#  Row(cuisines='Mexican,Traditional American'),
#  Row(cuisines='Mexican,Traditional American'),
#  Row(cuisines='Mexican,Traditional American'),
#  Row(cuisines='Mexican,Traditional American'),
#  Row(cuisines='Mexican,Traditional American'),
#  Row(cuisines='Mexican,Traditional American'),
#  Row(cuisines='Mexican,Traditional American'),
#  Row(cuisines='Mexican,Traditional American'),
#  Row(cuisines='Mexican,Traditional American'),
#  Row(cuisines='Mexican,Traditional American'),
#  Row(cuisines='Mexican,Traditional American'),
#  Row(cuisines='Mexican,Traditional American'),
#  Row(cuisines='Mexican,Traditional American'),
#  Row(cuisines='Mexican,Traditional American'),
#  Row(cuisines='Seafood'),
#  Row(cuisines='Burgers'),
#  Row(cuisines='Burgers'),
#  Row(cuisines='Burgers'),
#  Row(cuisines='Mexican Restaurants,Mexican'),
#  Row(cuisines='Mexican Restaurants,Mexican'),
#  Row(cuisines='Mexican Restaurants,Mexican'),
#  Row(cuisines='Mexican Restaurants,Mexican'),
#  Row(cuisines='Mexican Restaurants,Mexican'),
#  Row(cuisines='Mexican Restaurants,Mexican'),
#  Row(cuisines='Mexican Restaurants,Mexican'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Cafe'),
#  Row(cuisines='Sushi Bars'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Coffee Shops'),
#  Row(cuisines='Coffee Shops'),
#  Row(cuisines='Coffee Shops'),
#  Row(cuisines='Coffee Shops'),
#  Row(cuisines='Coffee Shops'),
#  Row(cuisines='Coffee Shops'),
#  Row(cuisines='Hotels'),
#  Row(cuisines='Hotels'),
#  Row(cuisines='Family Style Restaurants'),
#  Row(cuisines='Family Style Restaurants'),
#  Row(cuisines='Family Style Restaurants'),
#  Row(cuisines='Family Style Restaurants'),
#  Row(cuisines='Family Style Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='American'),
#  Row(cuisines='American'),
#  Row(cuisines='American'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Seafood'),
#  Row(cuisines='Seafood'),
#  Row(cuisines='Traditional American,Chinese'),
#  Row(cuisines='Traditional American,Chinese'),
#  Row(cuisines='Traditional American,Chinese'),
#  Row(cuisines='Hot Dogs'),
#  Row(cuisines='Pizza'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Southern'),
#  Row(cuisines='Bar / Lounge / Bottle Service, Gastro Pub, Tapas / Small Plates'),
#  Row(cuisines='Bar / Lounge / Bottle Service, Gastro Pub, Tapas / Small Plates'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Fast Food,Fast Food Restaurants'),
#  Row(cuisines='Take Out Restaurants,Pizza'),
#  Row(cuisines='Pizza'),
#  Row(cuisines='American'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='American Restaurants'),
#  Row(cuisines='Fast Food'),
#  Row(cuisines='American,Take Out Restaurants'),
#  Row(cuisines='American,Take Out Restaurants'),
#  Row(cuisines='American,Take Out Restaurants'),
#  Row(cuisines='American,Take Out Restaurants'),
#  Row(cuisines='American,Take Out Restaurants'),
#  Row(cuisines='American,Take Out Restaurants'),
#  Row(cuisines='American,Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Seafood, Steak, International'),
#  Row(cuisines='Seafood, Steak, International'),
#  Row(cuisines='Mexican, Bar / Lounge / Bottle Service, Tapas / Small Plates'),
#  Row(cuisines='Mexican, Bar / Lounge / Bottle Service, Tapas / Small Plates'),
#  Row(cuisines='Mexican, Bar / Lounge / Bottle Service, Tapas / Small Plates'),
#  Row(cuisines='Mexican, Bar / Lounge / Bottle Service, Tapas / Small Plates'),
#  Row(cuisines='Mexican, Bar / Lounge / Bottle Service, Tapas / Small Plates'),
#  Row(cuisines='Mexican, Bar / Lounge / Bottle Service, Tapas / Small Plates'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Chinese Restaurants'),
#  Row(cuisines='Chinese Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Mexican Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='American Restaurants,Pizza'),
#  Row(cuisines='American Restaurants,Pizza'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Restaurants'),
#  Row(cuisines='Hamburgers'),
#  Row(cuisines='American'),
#  Row(cuisines='Mexican,Mexican Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Coffee Shops'),
#  Row(cuisines='American'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Take Out Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Fast Food Restaurants'),
#  Row(cuisines='Seafood'),
#  Row(cuisines='Seafood'),
#  Row(cuisines='Seafood'),
#  Row(cuisines='Seafood'),
#  Row(cuisines='American, Gastro Pub, Seafood'),
#  Row(cuisines='American, Gastro Pub, Seafood'),
#  Row(cuisines='American, Gastro Pub, Seafood'),
#  Row(cuisines='American, Gastro Pub, Seafood'),
#  Row(cuisines='French American, American, Bar / Lounge / Bottle Service'),
#  Row(cuisines='Seafood,Seafood Restaurants'),
#  Row(cuisines='Seafood,Seafood Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Latin American Restaurants'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Traditional American'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  Row(cuisines='Mexican'),
#  ...]

# %%
def split_cuisines(x):
  x = x[0]                  # Nos aseguramos tomar el dato en particular
  x = x.replace(' ','')     # Reemplazamos los espacios, a no tenerlos 
  x = x.split(',')          # Dividimos por la coma
  return x

# Con esta función nos aseguramos que las observaciones con 2 o más tipos de cocina
# se separen. Eliminamos los espacios y dividimos por la coma

# %% [markdown]
# Con ayuda de flatMap aplicamos la función sobre cada uno de los elementos. A pesar de que flatmap es muy similar a map, es importante entender que en este caso particular necesitamos devolver varias elementos. Le pasamos a flatmap un RDD de N elementos y nos devuelve un nuevo RDD de M elementos, ello porque le solicitamos que transformara el RDD en donde en la columna cuisines se agregaban todos los tipos de cocina a uno en donde los separa de acuerdo con la función que definimos previamente.

# %%
flatmap  = A.flatMap(split_cuisines)

# %%
flatmap.collect() # Con collect nos muestra el resultado de la transformación
# Out:
# ['RestaurantDeliveryService',
#  'RestaurantDeliveryService',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'CoffeeShops',
#  'CoffeeShops',
#  'CoffeeShops',
#  'Mexican',
#  'LatinAmerican',
#  'Mexican',
#  'LatinAmerican',
#  'American',
#  'SeafoodRestaurants',
#  'American',
#  'SeafoodRestaurants',
#  'American',
#  'SeafoodRestaurants',
#  'American',
#  'SeafoodRestaurants',
#  'American',
#  'SeafoodRestaurants',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TakeOutRestaurants',
#  'Pizza',
#  'Pizza',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'Seafood',
#  'SeafoodRestaurants',
#  'Japanese',
#  'Thai',
#  'Hibachi',
#  'ContemporaryAmerican',
#  'WineBar',
#  'AfternoonTea',
#  'FastFoodRestaurants',
#  'Pizza',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'American(New)',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'ContemporaryAmerican',
#  'ComfortFood',
#  'Seafood',
#  'ContemporaryAmerican',
#  'ComfortFood',
#  'Seafood',
#  'Hamburgers',
#  'Fries',
#  'Shakes',
#  'Salads',
#  'TakeOutRestaurants',
#  'Pizza',
#  'FastFood',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Restaurants',
#  'Restaurants',
#  'Restaurants',
#  'Restaurants',
#  'Restaurants',
#  'ContemporaryAmerican',
#  'Bar/Lounge/BottleService',
#  'ContemporaryAmerican',
#  'Bar/Lounge/BottleService',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'ContemporaryAmerican',
#  'ContemporaryAmerican',
#  'ContemporaryAmerican',
#  'ContemporaryAmerican',
#  'ContemporaryAmerican',
#  'ContemporaryAmerican',
#  'ContemporaryAmerican',
#  'Yogurt',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'TakeOutRestaurants',
#  'Bars',
#  'Restaurants',
#  'TraditionalAmerican',
#  'HealthFood',
#  'Pizza',
#  'AsianFusion',
#  'TraditionalAmerican',
#  'HealthFood',
#  'Pizza',
#  'AsianFusion',
#  'TraditionalAmerican',
#  'HealthFood',
#  'Pizza',
#  'AsianFusion',
#  'TraditionalAmerican',
#  'HealthFood',
#  'Pizza',
#  'AsianFusion',
#  'TraditionalAmerican',
#  'HealthFood',
#  'Pizza',
#  'AsianFusion',
#  'American',
#  'Bar/Lounge/BottleService',
#  'American',
#  'Bar/Lounge/BottleService',
#  'American',
#  'Bar/Lounge/BottleService',
#  'NightClubs',
#  'NightClubs',
#  'AmericanRestaurants',
#  'American',
#  'ContemporaryAmerican',
#  'Southern',
#  'AmericanRestaurants',
#  'American',
#  'ContemporaryAmerican',
#  'Southern',
#  'AmericanRestaurants',
#  'American',
#  'ContemporaryAmerican',
#  'Southern',
#  'Taverns',
#  'Taverns',
#  'NewAmerican',
#  'TraditionalAmerican',
#  'FastFood',
#  'Hamburgers',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'TakeOutRestaurants',
#  'CoffeeShops',
#  'LatinAmericanRestaurants',
#  'LatinAmericanRestaurants',
#  'LatinAmericanRestaurants',
#  'LatinAmericanRestaurants',
#  'Mexican',
#  'Mexican',
#  'American',
#  'American',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'FastFood',
#  'Hamburgers',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Pizza',
#  'ContemporaryAmerican',
#  'Global',
#  'International',
#  'ContemporaryAmerican',
#  'Global',
#  'International',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'Pizzeria',
#  'Barbecue',
#  'Restaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'FastFood',
#  'Restaurants',
#  'Italian',
#  'LatinAmericanRestaurants',
#  'LatinAmericanRestaurants',
#  'LatinAmericanRestaurants',
#  'LatinAmericanRestaurants',
#  'Caterers',
#  'AmericanRestaurants',
#  'TraditionalAmerican',
#  'SandwichShops',
#  'AmericanRestaurants',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'SandwichShops',
#  'Restaurants',
#  'CoffeeShops',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'Restaurants',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'NewAmerican',
#  'Restaurants',
#  'Restaurants',
#  'Restaurants',
#  'Restaurants',
#  'Restaurants',
#  'Restaurants',
#  'FastFoodRestaurants',
#  'MexicanRestaurants',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'American',
#  'ContemporaryAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'Restaurants',
#  'Restaurants',
#  'Bars',
#  'Restaurants',
#  'JapaneseRestaurants',
#  'American',
#  'American',
#  'American',
#  'Pizza',
#  'TakeOutRestaurants',
#  'Hamburgers',
#  'Mexican',
#  'CoffeeShops',
#  'CoffeeShops',
#  'CoffeeShops',
#  'American',
#  'American',
#  'American',
#  'Restaurants',
#  'Restaurants',
#  'Pizza',
#  'FastFood',
#  'American',
#  'ContemporaryAmerican',
#  'American',
#  'JapaneseRestaurants',
#  'American',
#  'VegetarianFriendly',
#  'VeganOptions',
#  'GlutenFreeOptions',
#  'American',
#  'VegetarianFriendly',
#  'VeganOptions',
#  'GlutenFreeOptions',
#  'American',
#  'VegetarianFriendly',
#  'VeganOptions',
#  'GlutenFreeOptions',
#  'American',
#  'VegetarianFriendly',
#  'VeganOptions',
#  'GlutenFreeOptions',
#  'AmericanRestaurants',
#  'American',
#  'AmericanRestaurants',
#  'AmericanRestaurants',
#  'AmericanRestaurants',
#  'AmericanRestaurants',
#  'AmericanRestaurants',
#  'AmericanRestaurants',
#  'AmericanRestaurants',
#  'AmericanRestaurants',
#  'AmericanRestaurants',
#  'AmericanRestaurants',
#  'AmericanRestaurants',
#  'AmericanRestaurants',
#  'AmericanRestaurants',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'American',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'CoffeeShops',
#  'CoffeeShops',
#  'TakeOutRestaurants',
#  'Pub',
#  'Burgers',
#  'Burgers',
#  'Burgers',
#  'Burgers',
#  'Italian',
#  'American',
#  'American',
#  'American',
#  'ComfortFood',
#  'GastroPub',
#  'American',
#  'ComfortFood',
#  'GastroPub',
#  'CoffeeShops',
#  'TakeOutRestaurants',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Latin/Spanish',
#  'ContemporaryMexican',
#  'Mexican',
#  'Latin/Spanish',
#  'ContemporaryMexican',
#  'Seafood',
#  'Fusion/Eclectic',
#  'Lounge',
#  'Seafood',
#  'Fusion/Eclectic',
#  'Lounge',
#  'Seafood',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'Restaurants',
#  'Restaurants',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'TakeOutRestaurants',
#  'LatinAmericanRestaurants',
#  'American',
#  'ContemporaryAmerican',
#  'Tex-Mex',
#  'Mexican',
#  'Tex-Mex',
#  'Mexican',
#  'Tex-Mex',
#  'Mexican',
#  'FastFood',
#  'Hamburgers',
#  'FastFoodRestaurants',
#  'Restaurants',
#  'Burgers',
#  'Burgers',
#  'ContemporaryAmerican',
#  'American',
#  'American',
#  'ContemporaryFrench/American',
#  'Creole/Cajun/Southern',
#  'ChickenRestaurants',
#  'ChickenRestaurants',
#  'ChickenRestaurants',
#  'American',
#  'American',
#  'American',
#  'American',
#  'American',
#  'American',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'American',
#  'Diner',
#  'Delicatessen',
#  'American',
#  'Diner',
#  'Delicatessen',
#  'Tex-Mex',
#  'American',
#  'Pizza',
#  'Taverns',
#  'Pizza',
#  'Taverns',
#  'Pizza',
#  'Taverns',
#  'Pizza',
#  'Taverns',
#  'FastFoodRestaurants',
#  'TraditionalAmerican',
#  'Bars',
#  'AmericanRestaurants',
#  'Pizza',
#  'Cafeterias',
#  'Cafeterias',
#  'Cafeterias',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'Restaurants',
#  'Restaurants',
#  'Restaurants',
#  'Restaurants',
#  'AmericanRestaurants',
#  'AmericanRestaurants',
#  'AmericanRestaurants',
#  'AmericanRestaurants',
#  'Tapas/SmallPlates',
#  'Bar/Lounge/BottleService',
#  'Tapas/SmallPlates',
#  'Bar/Lounge/BottleService',
#  'Tapas/SmallPlates',
#  'Bar/Lounge/BottleService',
#  'FastFoodRestaurants',
#  'FastFoodRestaurants',
#  'FastFoodRestaurants',
#  'FastFoodRestaurants',
#  'FastFoodRestaurants',
#  'FastFoodRestaurants',
#  'FastFoodRestaurants',
#  'FastFoodRestaurants',
#  'FastFoodRestaurants',
#  'FastFoodRestaurants',
#  'FastFoodRestaurants',
#  'FastFoodRestaurants',
#  'FastFoodRestaurants',
#  'FastFoodRestaurants',
#  'FastFoodRestaurants',
#  'FastFoodRestaurants',
#  'FastFoodRestaurants',
#  'FastFoodRestaurants',
#  'FastFoodRestaurants',
#  'FastFoodRestaurants',
#  'FastFoodRestaurants',
#  'Pizza',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'Restaurants',
#  'American',
#  'Italian',
#  'Mediterranean',
#  'WineBar',
#  'AmericanRestaurants',
#  'AmericanRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'LatinAmericanRestaurants',
#  'LatinAmericanRestaurants',
#  'LatinAmericanRestaurants',
#  'LatinAmericanRestaurants',
#  'LatinAmericanRestaurants',
#  'LatinAmericanRestaurants',
#  'LatinAmericanRestaurants',
#  'LatinAmericanRestaurants',
#  'Pizza',
#  'Vegetarian',
#  'Pizza',
#  'Italian',
#  'Greek',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'AmericanRestaurants',
#  'FastFoodRestaurants',
#  'American',
#  'ComfortFood',
#  'American',
#  'American',
#  'Yogurt',
#  'Pizza',
#  'TakeOutRestaurants',
#  'Pizza',
#  'TakeOutRestaurants',
#  'Bagels',
#  'ComfortFood',
#  'Californian',
#  'ContemporaryAmerican',
#  'ComfortFood',
#  'Californian',
#  'ContemporaryAmerican',
#  'Hamburgers',
#  'Hamburgers',
#  'Hamburgers',
#  'Hamburgers',
#  'Italian',
#  'AmericanRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'LatinAmericanRestaurants',
#  'LatinAmericanRestaurants',
#  'LatinAmericanRestaurants',
#  'LatinAmericanRestaurants',
#  'Restaurants',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'American',
#  'Hamburgers',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Bars',
#  'American',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'FastFood',
#  'Vegetarian/Vegan',
#  'Global',
#  'International',
#  'Organic',
#  'Vegetarian/Vegan',
#  'Global',
#  'International',
#  'Organic',
#  'Restaurants',
#  'Restaurants',
#  'Restaurants',
#  'Restaurants',
#  'Restaurants',
#  'Restaurants',
#  'Restaurants',
#  'FastFood',
#  'CoffeeShops',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'TraditionalAmerican',
#  'Italian',
#  'Pizza',
#  'TakeOutRestaurants',
#  'Italian',
#  'Pizza',
#  'TakeOutRestaurants',
#  'Italian',
#  'Pizza',
#  'TakeOutRestaurants',
#  'Italian',
#  'Pizza',
#  'TakeOutRestaurants',
#  'Italian',
#  'Pizza',
#  'TakeOutRestaurants',
#  'Italian',
#  'Pizza',
#  'TakeOutRestaurants',
#  'AmericanRestaurants',
#  'Caterers',
#  'Caterers',
#  'Caterers',
#  'Caterers',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'MexicanRestaurants',
#  'American',
#  'Steak',
#  'Seafood',
#  'American',
#  'Steak',
#  'Seafood',
#  'American',
#  'Steak',
#  'Seafood',
#  'American',
#  'Steak',
#  'Seafood',
#  'Restaurants',
#  'Restaurants',
#  'Restaurants',
#  'Restaurants',
#  'Restaurants',
#  'Restaurants',
#  'Restaurants',
#  'Bars',
#  'Bars',
#  'Pizza',
#  'Mediterranean',
#  'Vegan',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'TakeOutRestaurants',
#  'LatinAmerican',
#  'Steak',
#  'Seafood',
#  'LatinAmerican',
#  'Steak',
#  'Seafood',
#  'LatinAmerican',
#  'Steak',
#  'Seafood',
#  'LatinAmerican',
#  'Steak',
#  'Seafood',
#  'LatinAmerican',
#  'Steak',
#  'Seafood',
#  'LatinAmerican',
#  'Steak',
#  'Seafood',
#  'LatinAmerican',
#  'Steak',
#  'Seafood',
#  'FamilyStyleRestaurants',
#  'FamilyStyleRestaurants',
#  'FamilyStyleRestaurants',
#  'FamilyStyleRestaurants',
#  'FamilyStyleRestaurants',
#  'FamilyStyleRestaurants',
#  'FastFoodRestaurants',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'Mexican',
#  'TraditionalAmerican',
#  'Mexican',
#  'TraditionalAmerican',
#  'Mexican',
#  'TraditionalAmerican',
#  'Mexican',
#  'TraditionalAmerican',
#  'Mexican',
#  'TraditionalAmerican',
#  'Mexican',
#  'TraditionalAmerican',
#  'Mexican',
#  'TraditionalAmerican',
#  'Mexican',
#  'TraditionalAmerican',
#  'Mexican',
#  'TraditionalAmerican',
#  'Mexican',
#  'TraditionalAmerican',
#  'Mexican',
#  'TraditionalAmerican',
#  'Mexican',
#  'TraditionalAmerican',
#  'Mexican',
#  'TraditionalAmerican',
#  'Mexican',
#  'TraditionalAmerican',
#  'Mexican',
#  'TraditionalAmerican',
#  'Mexican',
#  'TraditionalAmerican',
#  'Mexican',
#  'TraditionalAmerican',
#  'Mexican',
#  'TraditionalAmerican',
#  'Mexican',
#  'TraditionalAmerican',
#  'Mexican',
#  'TraditionalAmerican',
#  'Mexican',
#  'TraditionalAmerican',
#  'Seafood',
#  'Burgers',
#  'Burgers',
#  'Burgers',
#  'MexicanRestaurants',
#  'Mexican',
#  'MexicanRestaurants',
#  'Mexican',
#  'MexicanRestaurants',
#  'Mexican',
#  'MexicanRestaurants',
#  'Mexican',
#  'MexicanRestaurants',
#  'Mexican',
#  'MexicanRestaurants',
#  'Mexican',
#  'MexicanRestaurants',
#  'Mexican',
#  'TakeOutRestaurants',
#  'Cafe',
#  'SushiBars',
#  'TakeOutRestaurants',
#  'CoffeeShops',
#  'CoffeeShops',
#  'CoffeeShops',
#  'CoffeeShops',
#  'CoffeeShops',
#  'CoffeeShops',
#  'Hotels',
#  'Hotels',
#  'FamilyStyleRestaurants',
#  'FamilyStyleRestaurants',
#  'FamilyStyleRestaurants',
#  'FamilyStyleRestaurants',
#  'FamilyStyleRestaurants',
#  'TakeOutRestaurants',
#  'American',
#  ...]

# %% [markdown]
# Ahora aplicamos una nueva transformación en donde vamos a asignarle a cada columna un puntaje de 1. Después con ayuda de reduceByKey sumamos los puntajes de las observaciones que sean iguales. Por lo que tendremos entonces un objeto que por cada tipo de cocina nos indica el número de veces que se ha repetido.
#
# Finalmente con ayuda de sortBy ordenamos de forma descendente y nos muestra un ranking de los tipos de cocina más populares.

# %%
mapfun = flatmap.map(lambda x: (x,1))

# %%
results = mapfun.reduceByKey(lambda x,y: x+y)

# %%
results.sortBy(lambda x: x[1], ascending=False).collect()
# Out:
# [('Mexican', 10291),
#  ('TakeOutRestaurants', 5035),
#  ('MexicanRestaurants', 4034),
#  ('American', 3306),
#  ('TraditionalAmerican', 3033),
#  ('Restaurants', 2783),
#  ('FastFoodRestaurants', 2482),
#  ('LatinAmericanRestaurants', 1600),
#  ('Southwestern', 1573),
#  ('AmericanRestaurants', 1498),
#  ('Seafood', 1387),
#  ('ContemporaryAmerican', 1100),
#  ('Pizza', 832),
#  ('FastFood', 752),
#  ('Bars', 750),
#  ('Hamburgers', 595),
#  ('Mexican/Southwestern', 480),
#  ('CoffeeShops', 425),
#  ('LatinAmerican', 383),
#  ('Caterers', 376),
#  ('ComfortFood', 370),
#  ('Californian', 342),
#  ('Italian', 328),
#  ('ContemporaryMexican', 327),
#  ('Spanish', 325),
#  ('NewAmerican', 310),
#  ('Steak', 302),
#  ('Steakhouse', 299),
#  ('Burgers', 280),
#  ('FamilyStyleRestaurants', 264),
#  ('Bar/Lounge/BottleService', 259),
#  ('International', 244),
#  ('Barbecue', 226),
#  ('Mediterranean', 214),
#  ('Tapas/SmallPlates', 198),
#  ('GastroPub', 196),
#  ('Asian', 180),
#  ('Latin/Spanish', 175),
#  ('Tex-Mex', 172),
#  ('Southwest', 164),
#  ('TraditionalMexican', 163),
#  ('Latin', 162),
#  ('Vegetarian', 156),
#  ('VegetarianFriendly', 151),
#  ('Fusion/Eclectic', 151),
#  ('Chicken', 151),
#  ('Organic', 133),
#  ('Sushi', 130),
#  ('SeafoodRestaurants', 128),
#  ('Japanese', 126),
#  ('GlutenFreeOptions', 126),
#  ('BarbecueRestaurants', 121),
#  ('Global', 115),
#  ('VeganOptions', 109),
#  ('SouthAmerican', 104),
#  ('Vegetarian/Vegan', 103),
#  ('French', 100),
#  ('RegionalMexican', 100),
#  ('WineBar', 83),
#  ('SushiBars', 76),
#  ('Chinese', 74),
#  ('ItalianRestaurants', 73),
#  ('Irish', 73),
#  ('JapaneseRestaurants', 69),
#  ('Southern', 67),
#  ('Caribbean', 67),
#  ('Northwest', 63),
#  ('Cafeterias', 61),
#  ('Brewery', 59),
#  ('Vegan', 57),
#  ('ChineseRestaurants', 56),
#  ('Taverns', 55),
#  ('SandwichShops', 55),
#  ('Delicatessens', 55),
#  ('Continental', 55),
#  ('Deli', 53),
#  ('MediterraneanRestaurants', 52),
#  ('Soups', 51),
#  ('Pan-Asian', 50),
#  ('FrenchAmerican', 49),
#  ('Cafe', 48),
#  ('Pizzeria', 46),
#  ('American(Traditional)', 45),
#  ('VegetarianRestaurants', 44),
#  ('Diner', 43),
#  ('ChickenRestaurants', 42),
#  ('BrewPubs', 37),
#  ('CocktailLounges', 37),
#  ('SportsBars', 37),
#  ('GreekRestaurants', 37),
#  ('Bistro', 36),
#  ('Greek', 35),
#  ('HotDogs', 35),
#  ('SteakHouses', 35),
#  ('Cuban', 35),
#  ('AsianRestaurants', 35),
#  ('American(New)', 34),
#  ('HealthFood', 34),
#  ('NightClubs', 34),
#  ('Breakfast', 34),
#  ('Grocers-EthnicFoods', 34),
#  ('ThaiRestaurants', 33),
#  ('Sandwiches', 33),
#  ('Pub', 32),
#  ('Hawaiian', 32),
#  ('MexicanDescription', 31),
#  ('Wings', 30),
#  ('Indian', 28),
#  ('Bar', 27),
#  ('Korean', 26),
#  ('Peruvian', 25),
#  ('Sandwiches/Subs', 25),
#  ('Thai', 24),
#  ('Bakeries', 24),
#  ('Delicatessen', 23),
#  ('Bagels', 23),
#  ('Salads', 22),
#  ('Dessert', 22),
#  ('Polynesian', 22),
#  ('Yogurt', 21),
#  ('ContemporaryFrench/American', 18),
#  ('European', 18),
#  ('English', 18),
#  ('Creole/Cajun/Southern', 17),
#  ('ContemporaryAsian', 17),
#  ('BreakfastandBrunch', 16),
#  ('HawaiiRegionalCuisine', 16),
#  ('salate', 16),
#  ('burritos', 16),
#  ('quesadillas', 16),
#  ('salsa', 16),
#  ('beilagen', 16),
#  ('extras', 16),
#  ('BarFood', 15),
#  ('OysterBar', 15),
#  ('CoffeeShop', 15),
#  ('ContemporarySouthern', 15),
#  ('FineDiningRestaurants', 14),
#  ('Contemporary', 14),
#  ('ContemporaryEuropean', 14),
#  ('Moroccan', 14),
#  ('CentralAmerican', 14),
#  ('Hotels', 13),
#  ('MexicanCuisine', 13),
#  ('Cheesesteaks', 13),
#  ('Brazilian', 13),
#  ('PrimeRib', 13),
#  ('Soulfood', 13),
#  ('Fusion', 13),
#  ('MiddleEastern', 13),
#  ('ContemporaryFrench', 13),
#  ('Gastropub', 12),
#  ('Cajun', 12),
#  ('Donuts', 12),
#  ('VietnameseRestaurants', 11),
#  ('Healthy', 11),
#  ('Vietnamese', 11),
#  ('Hoagies/Grinders/Subs/Gyros', 11),
#  ('Pasta', 11),
#  ('Breakfast/Brunch', 11),
#  ('Wraps', 11),
#  ('Buffet', 10),
#  ('Burmese', 10),
#  ('Beverages', 10),
#  ('Calzones', 10),
#  ('FrenchFries/OnionRings', 10),
#  ('WhitePizza', 10),
#  ('Burgers/HotDogs', 10),
#  ('IndianRestaurants', 9),
#  ('SpanishRestaurants', 9),
#  ('Grill', 9),
#  ('ContemporaryItalian', 8),
#  ('Argentinean', 8),
#  ('BuffetRestaurants', 8),
#  ('HealthFoodRestaurants', 8),
#  ('EasternEuropean', 8),
#  ('IrishRestaurants', 8),
#  ('FamilyFare', 8),
#  ('Fries', 7),
#  ('Shakes', 7),
#  ('AsianFusion', 7),
#  ('BeerGarden', 7),
#  ('ContinentalRestaurants', 7),
#  ('Ranches', 7),
#  ('CaribbeanRestaurants', 7),
#  ('Persian', 7),
#  ('FrenchRestaurants', 7),
#  ('Asian/Pacific', 7),
#  ('Traditional', 7),
#  ('Karaoke', 7),
#  ('BurgersDescription', 7),
#  ('BrazilianSteakhouse', 7),
#  ('RestaurantDeliveryService', 6),
#  ('Portuguese', 6),
#  ('ModernEuropean', 6),
#  ('Delis', 6),
#  ('MexicanGoods', 6),
#  ('MiddleEasternRestaurants', 6),
#  ('DessertRestaurants', 6),
#  ('CoffeeandTea', 6),
#  ('FamilyStyle', 6),
#  ('Creole', 6),
#  ('Belgian', 6),
#  ('Lodging', 6),
#  ('Eclectic', 6),
#  ('NativeAmerican', 6),
#  ('ChainRestaurant', 5),
#  ('Bakery', 5),
#  ('British', 5),
#  ('Jamaican', 5),
#  ('WildGame', 5),
#  ('WholesaleMeat', 5),
#  ('CubanRestaurants', 5),
#  ('French(Bistro)', 5),
#  ('Colombian', 5),
#  ('PoolHalls', 5),
#  ('ContemporaryIndian', 4),
#  ('Pretzels', 4),
#  ('SouthernAmerican', 4),
#  ('German', 4),
#  ('Kosher', 4),
#  ('PuertoRican', 4),
#  ('Filipino', 4),
#  ('Bowling', 4),
#  ('Desserts', 4),
#  ('Swedish', 4),
#  ('Farm-to-table', 4),
#  ('Vegetarian-Friendly', 4),
#  ('DonutShops', 4),
#  ('Fish', 4),
#  ('AmericanCuisine', 4),
#  ('KosherRestaurants', 4),
#  ('SocialServiceOrganizations', 4),
#  ('SmallPlates/Tapas', 4),
#  ('Cocktails', 4),
#  ('Tapas', 3),
#  ('Israeli', 3),
#  ('Coffeehouse', 3),
#  ('SouthAfrican', 3),
#  ('PacificRim', 3),
#  ('SteakHouse', 3),
#  ('NewYorkStylePizza', 3),
#  ('Stromboli', 3),
#  ('InternetCafes', 3),
#  ('Fondue', 3),
#  ('SandwichesCuisine', 3),
#  ('FamilyStyleCuisine', 3),
#  ('Steakhouses', 3),
#  ('Lounge', 2),
#  ('Motels', 2),
#  ('PizzaByTheSlice', 2),
#  ('DiningBar', 2),
#  ('HomemadePasta', 2),
#  ('ItalianDishes', 2),
#  ('DeepSkillet/PanPizza', 2),
#  ('Australian', 2),
#  ('FriedChicken', 2),
#  ('Specialties', 2),
#  ('Cheesesteak', 2),
#  ('GourmetShops', 2),
#  ('Canadian', 2),
#  ('Noodle', 2),
#  ('ItalianGroceryStores', 2),
#  ('Homecooking', 2),
#  ('Salvadoran', 2),
#  ('Regiomontana', 2),
#  ('Hibachi', 1),
#  ('AfternoonTea', 1),
#  ('FishingPiers', 1),
#  ('Russian', 1),
#  ('French/Canadian', 1),
#  ('FoodDeliveryService', 1),
#  ('Tacos', 1),
#  ('Resorts', 1),
#  ('Coffee', 1),
#  ('Smoothies', 1),
#  ('Tea', 1),
#  ('Juices', 1),
#  ('Casinos', 1),
#  ('GlutenFree', 1),
#  ('LowCountry', 1),
#  ('Indonesian', 1),
#  ('Provencal', 1),
#  ('French/Japanese', 1),
#  ('MeatMarkets', 1),
#  ('Asianfusion', 1),
#  ('VeganRestaurants', 1),
#  ('TeaDescription', 1),
#  ('SmallPlates', 1),
#  ('PartyTrays', 1),
#  ('HomemadeDough', 1),
#  ('Antipasta', 1),
#  ('FullDelicatessen', 1),
#  ('WholeWheatCrust', 1),
#  ('SicilianPizza', 1),
#  ('TomatoPie', 1),
#  ('NeapolitanStylePizza', 1),
#  ('VegetarianToppings', 1),
#  ('BrickOvenPizza', 1),
#  ('StoneBakedPizza', 1),
#  ('SeafoodDishes', 1),
#  ('SoulFood', 1),
#  ('HotChicken', 1),
#  ('Buffets', 1),
#  ('HawaiianRestaurants', 1),
#  ('GolfCourses', 1),
#  ('Countrykitchen', 1),
#  ('ConvenienceStores', 1),
#  ('Lebanese', 1),
#  ('FoodProducts', 1),
#  ('Diners', 1),
#  ('Afghan', 1)]

# %% [markdown]
# #### Conclusión y Resultados
#
# Con ayuda de PySpark encontramos que dentro de los restaurantes que ofrecen Tacos y Burritos, el tipo de cocina más común corresponde a 'Mexican' con 10291 restaurantes, seguido de 'TakeOutRestaurants' con 5034 restaurantes.
